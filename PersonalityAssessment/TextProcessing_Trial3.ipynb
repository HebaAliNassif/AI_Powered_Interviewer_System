# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

import nltk 
import num2words

import re
import pickle
import os
import time
import string

# %%
from sklearn.model_selection import train_test_split

# %%
from nltk import wordpunct_tokenize, word_tokenize, WordNetLemmatizer, sent_tokenize, pos_tag

# %% [markdown]
# ---

# %% [markdown]
# ### Loading Dataset

# %%
# Load from .csv file with complete dataset
data_essays = pd.read_csv('essays.csv', encoding = "ISO-8859-1")
data_essays['cEXT'] = np.where(data_essays['cEXT']=='y', 1, 0)
data_essays['cNEU'] = np.where(data_essays['cNEU']=='y', 1, 0)
data_essays['cAGR'] = np.where(data_essays['cAGR']=='y', 1, 0)
data_essays['cCON'] = np.where(data_essays['cCON']=='y', 1, 0)
data_essays['cOPN'] = np.where(data_essays['cOPN']=='y', 1, 0)

X_essays = data_essays['TEXT']
y_essays = data_essays[['cEXT', 'cNEU', 'cAGR', 'cCON', 'cOPN']]

data_essays['text length'] = data_essays['TEXT'].apply(len)

labels = ['cEXT', 'cNEU', 'cAGR', 'cCON', 'cOPN']
X_train, X_test, y_train, y_test = train_test_split(X_essays, y_essays, test_size=0.05)

# %%
print(X_test)
# Out:
# 503     Since I am already on the computer I am going ...
# 1025    my thoughts, feelings, and sensations?  right ...
# 2374         Oh man I'm so hungry. I can't wait for th...
# 873     I really wish people would be more efficient w...
# 524     I work at a daycare in the mornings on Teusday...
#                               ...
# 2405         I'm writing this assignment feeling kind ...
# 310     This the third time that I am typing this thin...
# 121     Okay. I'm in the stupid SMURF lab. there are s...
# 70      College seems very stressful. It's not like hi...
# 1622          I am a little irritated right now. I jus...
# Name: TEXT, Length: 124, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ### Preprocessing Data

# %% [markdown]
# #### Lower Casing

# %%
def convert_lower_case(data):
    data = data.str.lower()

# %%
X_test = convert_lower_case(X_test)

# %% [markdown]
# #### Removing Stopwords

# %%
stop_words = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# #### Removing Punctuation

# %%
punctuations = ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %% [markdown]
# #### Cleaning Text

# %%
def clean_text(data):
    data = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", data)
    data = re.sub(r"what's", "what is ", data)
    data = re.sub(r"\'s", " ", data)
    data = re.sub(r"\'ve", " have ", data)
    data = re.sub(r"can't", "cannot ", data)
    data = re.sub(r"n't", " not ", data)
    data = re.sub(r"I'm", "I am ", data)
    data = re.sub(r"\'re", " are ", data)
    data = re.sub(r"\'d", " would ", data)
    data = re.sub(r"\'ll", " will ", data)
    
    # Convert numbers from digits to words
    data = re.sub(r"(\d+)", lambda x: num2words.num2words(int(x.group(0))), data)

    #data = re.sub(r'[^\w\s]', '', data)
    #data = re.sub(r"(\d+)(k)", r"\g<1>000", data)
    return data

# %% [markdown]
# #### Lemmatization

# %%
def lemmatize_token(token, tag):
    tag = {
        'N': nltk.corpus.wordnet.NOUN,
        'V': nltk.corpus.wordnet.VERB,
        'R': nltk.corpus.wordnet.ADV,
        'J': nltk.corpus.wordnet.ADJ
    }.get(tag[0], nltk.corpus.wordnet.NOUN)
    return WordNetLemmatizer().lemmatize(token, tag)

# %% [markdown]
# #### Preprocessing

# %%
def preprocess_text(X):
    """
    Returns a preprocessed version of a full corpus (ie. tokenization and lemmatization using POS taggs)
    """
    #X = ' '.join(X_corpus)
    lemmatized_tokens = []


    # Clean the text
    X = clean_text(X)


    # Break the text into sentences
    for sent in sent_tokenize(X):
        
        # Remove punctuation
        #sent = remove_punctuation(sent)

        # Break the sentence into part of speech tagged tokens
        for token, tag in pos_tag(word_tokenize(sent)):

            # Apply preprocessing to the token
            token = token.lower()
            token = token.strip()
            token = token.strip('_')
            token = token.strip('*')

            # If punctuation or stopword, ignore token and continue
            #if token in set(stopwords.words('english')) or all(char in set(string.punctuation) for char in token):

            # Removing stopwords, punctuation and one-letter words
            if token in set(stop_words) or token in punctuations or len(token) == 1:
                continue

            # Lemmatize the token
            lemma = lemmatize_token(token, tag)
            lemmatized_tokens.append(lemma)


    doc = ' '.join(lemmatized_tokens)

    return doc

# %% [markdown]
# ---

# %% [markdown]
# #### Applying Preprocessing on Dataset

# %%
numberOfDocuments = len(X_test)
dataset = []
for i in range(numberOfDocuments):
    dataset.append(preprocess_text(X_test.iloc[i]))

# %%
print(dataset)
# Out:
# ['since already computer go one write assignment good wont worry later take care thing list much close go home like new place big cold best buds live theyre cool except new guy jon fella really stick as respect work full time usually tire come work give special right except get paychek sure mean roommate feel sorry get thing tell go problem already word several time blow mind guy willing let escalate fistfight less minute mean get live whole year one thinking really get raw tell handle thing civilized society especially mine want shack cap bob realize tight anybody get rough also bob girlfriend become permanent fixture already understand live pay rent carry relationship simultaneously everyone else love bob death woman good engage still give everybody look leave room feel sorry probably glad still think reason bitch thing frustrate see bros together like like half boy dobie last year even come back clincher real salt wound none could mentally make fucking lazy unmotivated piss away best friend ever keep touch talk always feel twinge anger fill thier end bargain say back next semester believe lot lazy even see miss enough get attention stay focused stay ut', 'thought feeling sensation right eye feel vacant heart feel heavy moment dorm silence others sound ani enlighten lyric via stereo hide behind facade smile need unless concern impress professor sort great stream consiousness piece writing consiousness suppose really interesting worried one sensation rip vein worried fail french teach someone new language language understand worried thing voice anywhere worried thing suppose talk stranger family friend unless mind burden god help ugly girl course pretty also doom ani say know mean felt way often choose ugly girl though good deal afraid never fully understand truth come austin college didnt realize risk pretty girl take strange turn sorry havent quite figure regulate stream consiousness think think pretty god hope oh please let someone else get elevator u leave alone fast run approach everyday thought never use like ashamed girl become last week discover several thing since last tuesday sense righteous babe ani term think scared little girl stand hurt prove week lieu retaliation justice cower shadow cling boyfriend cry sleep mind full thought many sort prominant one come screen apologize happy one one say much love college life psychology class worthy many thing think maybe hypothalamus secrete enough happy stuff feeling great moment perhaps choose write time naive stupid thought allow horror happen boyfriend nothing write someone never speak read miss little brother baby four year old brother favorite person entire world look picture hold wooden sword pretend either david crockett obi wan kenobi welp twenty minute thank doctor', 'oh man hungry wait football game tonight go lot fun wow think really fast cause think three thing hunger football giant pre-screening survey thing take believe finish two fifty-four six minute leave stop accept man talk pressure speak pressure thought physic kind weird since physic year math though play card last time class play crazy russian game really cool tie end wow ok type think anime forum since use forum time anime face think type without look keyboard move mouse remind real mouse man make lot typo well know learn type early lift hand keyboard could type fast since small hand think tenth grade fix retaught ten finger typing cause see hover hand type cause look keyboard song change totaly distract speak song meet girl name helen song first day psycology really cool like lot friend time want ask know big fear pretty much one lose friend trouble ask girl cause afraid say want friend anymore tell oh well know read read completely hehe know people type hehe haha tell u think reaction observation bet lot people start talk observing rather think pay attention random observation thought bet produce lot weird data well ask lot question think really fast often find daydream time hehe yeah wow hehe soun ...

# %% [markdown]
# #### Calculating Document Frequency

# %%
DF = {}

#Set word as the key and the list of doc id’s as the value
for i in range(numberOfDocuments):
    tokens = dataset[i]

    for w in tokens.split():
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}

# Replace the list of docs with its count
for i in DF:
    DF[i] = len(DF[i])

# %%
total_vocab = [x for x in DF]

# %% [markdown]
# #### Calculating Term Frequency-Inverse Document Frequency

# %%
from collections import Counter

# %%
def doc_freq(text, s): 
        if text in s:
            loc = list(s).index(text)
            value_at_index = list(s.values())[loc]
            return value_at_index

# %%
tf_idf = {}
N = len(dataset)

for i in range(N):
    tokens = dataset[i].split()
    words_count = len(tokens)
    counter = Counter(tokens)
    for token in np.unique(tokens):
        tf = counter[token]/words_count
        df = doc_freq(token, DF)
        idf = np.log(N/(df+1))
        tf_idf[i, token] = tf*idf

# %%
tf_idf
# Out:
# {(0, 'already'): 0.019906477553675007,
#  (0, 'also'): 0.0034725478934025853,
#  (0, 'always'): 0.0029322375566957835,
#  (0, 'anger'): 0.02116479171817996,
#  (0, 'anybody'): 0.015530882545522985,
#  (0, 'as'): 0.013451574298814448,
#  (0, 'assignment'): 0.004358921292579051,
#  (0, 'attention'): 0.014055589866283082,
#  (0, 'away'): 0.005198046542742138,
#  (0, 'back'): 0.004886934807706185,
#  (0, 'bargain'): 0.02116479171817996,
#  (0, 'become'): 0.00935666303615921,
#  (0, 'believe'): 0.004975045968692196,
#  (0, 'best'): 0.012403729773957052,
#  (0, 'big'): 0.005802062110210772,
#  (0, 'bitch'): 0.01908548347147142,
#  (0, 'blow'): 0.013451574298814448,
#  (0, 'bob'): 0.052830572376694564,
#  (0, 'boy'): 0.011185765312768093,
#  (0, 'bros'): 0.02116479171817996,
#  (0, 'buds'): 0.02116479171817996,
#  (0, 'cap'): 0.02116479171817996,
#  (0, 'care'): 0.007277354789450675,
#  (0, 'carry'): 0.017610190792231518,
#  (0, 'civilized'): 0.02116479171817996,
#  (0, 'clincher'): 0.02116479171817996,
#  (0, 'close'): 0.007277354789450675,
#  (0, 'cold'): 0.010500988940334643,
#  (0, 'come'): 0.00411734315700963,
#  (0, 'computer'): 0.005198046542742138,
#  (0, 'cool'): 0.006065104645531545,
#  (0, 'could'): 0.0017586910314196433,
#  (0, 'death'): 0.014055589866283082,
#  (0, 'dobie'): 0.01908548347147142,
#  (0, 'else'): 0.0055518561401111215,
#  (0, 'end'): 0.007277354789450675,
#  (5, 'brittnay'): 0.03091486430745387,
#  (5, 'brother'): 0.007025627664564031,
#  (5, 'caring'): 0.015457432153726936,
#  (5, 'change'): 0.008859141617068548,
#  (5, 'child'): 0.0349868901245998,
#  (5, 'class'): 0.0016414042356972108,
#  (5, 'college'): 0.013594325906047497,
#  (5, 'commonplace'): 0.015457432153726936,
#  (5, 'concern'): 0.009824183476662238,
#  (5, 'consumes'): 0.015457432153726936,
#  (5, 'cook'): 0.015457432153726936,
#  (5, 'cooking'): 0.015457432153726936,
#  (5, 'cousin'): 0.010265318441667419,
#  (5, 'dad'): 0.006310064980059503,
#  (5, 'day'): 0.003968705052109706,
#  (5, 'dearly'): 0.015457432153726936,
#  (5, 'difference'): 0.012025631659816242,
#  (5, 'different'): 0.004332284342604458,
#  (5, 'dinner'): 0.012025631659816242,
#  (5, 'divorce'): 0.012861375297697177,
#  (5, 'else'): 0.004054726394463179,
#  (5, 'engage'): 0.013938836243209464,
#  (5, 'enjoyable'): 0.012861375297697177,
#  (5, 'enter'): 0.012025631659816242,
#  (5, 'envious'): 0.015457432153726936,
#  (5, 'ever'): 0.0035546088190904347,
#  (5, 'every'): 0.0037963261267217868,
#  (5, 'exam'): 0.013938836243209464,
#  (5, 'exciting'): 0.013938836243209464,
#  (5, 'expect'): 0.006833517947756726,
#  (5, 'extremely'): 0.01134277938717971,
#  (5, 'family'): 0.008474922183453937,
#  (5, 'fancy'): 0.015457432153726936,
#  (5, 'far'): 0.004529451883748361,
#  (5, 'feel'): 0.003600807812076087,
#  (5, 'feeling'): 0.0051921137120595155,
#  (5, 'figure'): 0.00570953071011501,
#  (5, 'find'): 0.0065096467941843416,
#  (5, 'first'): 0.0032548233970921708,
#  (5, 'focus'): 0.008446937109151688,
#  (5, 'four'): 0.009264139529205444,
#  (5, 'freshman'): 0.007025627664564031,
#  (5, 'friend'): 0.0014586695384334206,
#  (5, 'funny'): 0.005073204729607904,
#  (5, 'generous'): 0.015457432153726936,
#  (5, 'get'): 0.00024978042883397805,
#  (5, 'girl'): 0.0036334605389325026,
#  (5, 'go'): 0.00024561665035948294,
#  (5, 'good'): 0.0021549218910245755,
#  (5, 'gossipy'): 0.015457432153726936,
#  (5, 'grade'): 0.012301331350240384,
#  (5, 'guy'): 0.0032548233970921708,
#  (5, 'happy'): 0.004737578667099712,
#  (5, 'hard'): 0.004176791674634617,
#  (5, 'heart'): 0.007442203076961875,
#  (5, 'help'): 0.0036334605389325026,
#  (5, 'high'): 0.011142024372089235,
#  (5, 'honest'): 0.012861375297697177,
#  (5, 'hope'): 0.0025361304839457083,
#  (5, 'however'): 0.007442203076961875,
#  (5, 'husband'): 0.01134277938717971,
#  (5, 'impact'): 0.013938836243209464,
#  (5, 'instance'): 0.015457432153726936,
#  (5, 'interest'): 0.007228126620632481,
#  ...}

# %% [markdown]
# #### Document Vectorization

# %%
# Document Vectorization
D = np.zeros((N, len(total_vocab)))
for i in tf_idf:
    ind = total_vocab.index(i[1])
    D[i[0]][ind] = tf_idf[i]

# %% [markdown]
# ---
